# %% [markdown]
# # Experiment analysis
# Plan waiting times and analyze a CSV containing time and signal columns.

# %%
from julia.api import Julia
Julia(compiled_modules=False)
from julia import DavydovFoldon as df
plan = df.design_pulse_sequence((0.0, 5.0), step=0.05)
print(plan)
# result = df.analyze_beats("experimental_signal.csv", predicted_beat_freq=1.2)
